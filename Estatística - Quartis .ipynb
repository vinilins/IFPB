# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randint(0,100,size=(100,4)),columns=list('ABCD'))
df
# Out:
#      A   B   C   D
# 0   67  48  15  24
# 1    9   4  28  82
# 2   91  28  26   1
# 3    5  80  65  82
# 4   72  62   8  99
# 5   46  81  86  89
# 6   22  51  67  21
# 7   82  79  35  30
# 8   97  68  23  24
# 9   31  22  39  43
# 10  63  69  64  62
# 11  93  28  93  34
# 12  86  40  35   2
# 13  84  11  96  67
# 14  86  89   5  30
# 15  60  95  20  15
# 16  96  20   4   3
# 17   5  34  99   8
# 18  83  53  94  95
# 19  48  79  12  47
# 20  88  42  62  30
# 21  59  53   8  70
# 22  75  62  21  33
# 23  89  79  51  96
# 24  29  80  83  84
# 25  20  53  39  83
# 26  14  91  56  56
# 27  58  43  33  96
# 28  85  70  69  97
# 29  55  17  92  38
# ..  ..  ..  ..  ..
# 70   0  17  74   3
# 71  98  53  93  81
# 72  65  10  71  43
# 73  20   0   6   6
# 74  43  10  35  50
# 75  47  63  82  87
# 76  40  64  96  69
# 77  22   8  79  43
# 78  84  10  31  27
# 79  75  76  85  94
# 80  86  65  15  38
# 81  87  82  85  23
# 82  86  36  43  81
# 83  11  75   3  61
# 84  17  33  76  81
# ...

# %%
df.quantile(q=0.5,axis=0,numeric_only=True,interpolation='linear')
# Out:
# A    50.5
# B    48.0
# C    51.0
# D    43.5
# Name: 0.5, dtype: float64

# %%
df.quantile(q=0.25,axis=0)
# Out:
# A    23.75
# B    28.00
# C    25.00
# D    24.00
# Name: 0.25, dtype: float64

# %%
df.quantile(q=0.75,axis=0)
# Out:
# A    82.25
# B    75.00
# C    77.00
# D    74.25
# Name: 0.75, dtype: float64

# %%
df.quantile(q=[0.25,0.5,0.75])
# Out:
#           A     B     C      D
# 0.25  23.75  28.0  25.0  24.00
# 0.50  50.50  48.0  51.0  43.50
# 0.75  82.25  75.0  77.0  74.25

# %%
a = pd.read_csv('C:/Users/ifpb/Desktop/winemag-data_first150k.csv')
a
# Out:
#         Unnamed: 0      country  \
# 0                0           US
# 1                1        Spain
# 2                2           US
# 3                3           US
# 4                4       France
# 5                5        Spain
# 6                6        Spain
# 7                7        Spain
# 8                8           US
# 9                9           US
# 10              10        Italy
# 11              11           US
# 12              12           US
# 13              13       France
# 14              14           US
# 15              15           US
# 16              16           US
# 17              17        Spain
# 18              18       France
# 19              19           US
# 20              20           US
# 21              21        Spain
# 22              22        Spain
# 23              23           US
# 24              24           US
# 25              25  New Zealand
# 26              26           US
# 27              27           US
# ...

# %%
a.price.hist(bins=500)

# %%
a.points.hist()

# %%
price = a['price'].quantile(q=[0.25,0.5,0.75])
price
# Out:
# 0.25    16.0
# 0.50    24.0
# 0.75    40.0
# Name: price, dtype: float64

# %%
price.plot()

# %%
points = a['points'].quantile(q=[0.25,0.5,0.75])
points
# Out:
# 0.25    86.0
# 0.50    88.0
# 0.75    90.0
# Name: points, dtype: float64

# %%
points.plot()
